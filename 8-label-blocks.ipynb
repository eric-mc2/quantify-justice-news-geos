# %% [markdown]
# **TODO**:
#
# Read in the geocoded stuff.
# Check nan percent of community area.
# Filter for blocks.
# Label the blocks.
# Check nan percent of community area again.
# Pick next type of location to fix.
# Or use geocodes as training data for non-block location classifier.
